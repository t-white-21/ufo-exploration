# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import requests
from bs4 import BeautifulSoup as BS
import re
import time

# %%
from selenium import webdriver
from selenium.webdriver.support.select import Select
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %%
#this is from Melanie Wesson, DA Cohort 6

#set up browser
s = Service("C:\Program Files (x86)\chromedriver.exe")
#opts= Options()
#opts.headless = True
driver = webdriver.Chrome(service = s)
driver.get("https://nuforc.org/subndx/?id=all")

# %%
#URL = "https://nuforc.org/subndx/?id=e202312"
#page = requests.get(URL)
#soup = BS(page.content, "lxml")

#print(page.text)

# %%
#results = soup.find('tbody')

# %%
#rows = results.find_all('tr')

# %% [markdown]
# This gives me 5 repeats of each row.
#
# occured = []
# city = []
# state = []
# country = []
# shape = []
# summary = []
# reported = []
# posted = []
# image = []
#
# for page in range (0,10):
#       for x in range(0,100):
#             o = rows[x].find_all('td', style='')[1].text.strip()
#             c = rows[x].find_all('td', style='')[2].text.strip()
#             s = rows[x].find_all('td', style='')[3].text.strip()
#             co = rows[x].find_all('td', style='')[4].text.strip()
#             sh = rows[x].find_all('td', style='')[5].text.strip()
#             sum = rows[x].find_all('td', style='')[6].text.strip()
#             r = rows[x].find_all('td', style='')[7].text.strip()
#             p = rows[x].find_all('td', style='')[8].text.strip()
#             i = rows[x].find_all('td', style='')[9].text.strip()
#
#             occured.append(o)
#             city.append(c)
#             state.append(s)
#             country.append(co)
#             shape.append(sh)
#             summary.append(sum)
#             reported.append(r)
#             posted.append(p)
#             image.append(i)
#
#
#       button = driver.find_element(By.CLASS_NAME, 'paginate_button.next')
#       button.click()
#       time.sleep(5)
#
# #print(country)
#       #WebDriverWait(driver, 20).until(EC.invisibility_of_element_located((By.CSS_SELECTOR, "div.loader-overlay#loader[ng-show='loading'][aria-labelledby='loading-msg']")))
#       #WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "label[for='no-renovate']"))).click()

# %%
# all_list_elements = driver.find_element(By.XPATH, '//*[@id="table_1_paginate"]/span')
# number_of_pages = int(all_list_elements[-2].text)

# %%
#https://www.geeksforgeeks.org/how-to-scrape-multiple-pages-using-selenium-in-python/

occurred = []
city = []
state = []
country = []
shape = []
summary = []
reported = []
posted = []
image = []

for page in range (1,3):
      #driver.get("https://nuforc.org/subndx/?id=all")
      URL = "https://nuforc.org/subndx/?id=all"
      page = requests.get(URL)
      soup = BS(page.content, "lxml")
      results = soup.find('tbody')
      rows = results.find_all('tr')

      #doesnt't make a difference where my buttons are (before or after).

      # button = driver.find_element(By.CLASS_NAME, 'paginate_button.next')
      # button.click()
      # time.sleep(5)
      
      for x in range(0,100):
            o = rows[x].find_all('td', style='')[1].text.strip()
            c = rows[x].find_all('td', style='')[2].text.strip()
            s = rows[x].find_all('td', style='')[3].text.strip()
            co = rows[x].find_all('td', style='')[4].text.strip()
            sh = rows[x].find_all('td', style='')[5].text.strip()
            sum = rows[x].find_all('td', style='')[6].text.strip()
            r = rows[x].find_all('td', style='')[7].text.strip()
            p = rows[x].find_all('td', style='')[8].text.strip()
            i = rows[x].find_all('td', style='')[9].text.strip()
   
            occurred.append(o)
            city.append(c)
            state.append(s)
            country.append(co)
            shape.append(sh)
            summary.append(sum)
            reported.append(r)
            posted.append(p)
            image.append(i)

            print(f'{x}:{o}, {c}')


            #break <-- gives 10 of the same result
 #https://stackoverflow.com/questions/75479097/scrape-multiple-pages-with-the-same-url-using-python-selenium        
      #btnNext = driver.find_element(By.XPATH,'//*[@id="table_1_next"]')
      #driver.execute_script("arguments[0].scrollIntoView();", btnNext)
      #driver.execute_script("arguments[0].click();", btnNext)
      
      # button = driver.find_element(By.CLASS_NAME, 'paginate_button.next')
      # button.click()
      # time.sleep(5)
      


      #WebDriverWait(driver, 20).until(EC.invisibility_of_element_located((By.CSS_SELECTOR, "div.loader-overlay#loader[ng-show='loading'][aria-labelledby='loading-msg']")))
      #WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "label[for='no-renovate']"))).click()
# Out:
# 0:02/02/1995 23:00, Shady Grove
# 1:02/02/1995 19:15, Denmark
# 2:02/02/1995 20:10, Traverse City
# 3:12/13/1994 18:55, Murphy
# 4:02/03/1995 23:25, Fontana
# 5:02/04/1995 00:00, New Orleans
# 6:02/04/1995 17:33, Lewiston
# 7:02/04/1995 19:10, Port Hadlock
# 8:02/04/1995 19:00, Chimacum
# 9:02/05/1995 00:00, Atlanta
# 10:02/04/1995 15:05, Lynnwood
# 11:02/07/1995 04:55, Quilcene
# 12:02/06/1995 00:00, Bloomington
# 13:02/06/1995 19:30, Nine Mile Falls
# 14:02/05/1995 01:30, Greensville
# 15:02/07/1995 23:00, Tidewater
# 16:02/07/1995 21:10, Shawnee
# 17:02/07/1995 00:00, Seattle
# 18:02/07/1995 00:00, Raymond
# 19:02/07/1995 20:35, Tacoma
# 20:02/06/1995 18:28, Little Rock
# 21:02/08/1995 18:32, Renton
# 22:02/08/1995 05:30, North Bend
# 23:02/09/1995 00:00, Huntington Beach
# 24:02/09/1995 00:00, Auburn
# 25:02/09/1995 19:00, Vancouver
# 26:02/10/1995 00:00, Seattle
# 27:02/08/1995 00:00, Tillamook
# 28:01/01/1990 00:00, Minneapolis
# 29:01/01/1993 00:00, Reedborough
# 30:02/03/1995 21:30, Romulus
# 31:02/04/1995 18:45, Lewiston
# 32:02/02/1995 04:00, Seatac
# 33:02/12/1995 00:45, Elizabethtown
# 34:02/12/1995 21:00, El Cerrito
# 35:02/14/1995 23:28, Chico
# 36:01/15/1995 21:00, Morton
# 37:02/15/1995 04:40, Fair Oaks
# 38:02/15/1995 03:58, Nashville
# 39:02/13/1995 22:15, Cheboygan
# 40:02/12/1995 06:25, McKinleyville
# 41:02/15/1995 21:00, Santa Rosa
# 42:02/16/1995 00:00, Johnson City
# 43:02/16/1995 00:00, Sacramento
# 44:02/16/1995 19:26, Albuquerque
# 45:02/16/1995 23:15, Paw Paw
# 46:02/16/1995 23:10, Kalamazoo
# 47:02/16/1995 23:45, Des Plaines
# 48:02/17/1995 22:30, Seatac
# 49:02/16/1995 23:45, Kalamazoo
# 50:02/18/1995 18:00, Warren
# 91:02/26/1995 20:00, Tallassee
# 92:02/28/1995 05:00, Electric City
# 93:12/08/1994 02:45, McCall
# 94:12/31/1994 22:00, Orem
# 95:12/29/1994 21:45, La Crosse
# 96:01/01/1995 22:45, Anaheim
# 97:01/01/1995 19:50, Warm Beach
# 98:01/02/1995 06:25, New Port Richey
# 99:01/03/1995 23:45, Salinas

# %% [markdown]
# read this tomorrow:
#
# https://stackoverflow.com/questions/71243047/selenium-common-exceptions-elementclickinterceptedexception-message-element-cl

# %%
#https://www.geeksforgeeks.org/how-to-click-a-button-on-webpage-using-selenium/

# getting the button by class name
# button = driver.find_element_by_class_name("slide-out-btn")
 
# clicking on the button
# button.click()

#https://selenium-python.readthedocs.io/locating-elements.html

# button = driver.find_element(By.CLASS_NAME, 'paginate_button.next')
# button.click()

# time.sleep(10)

# %%
len(city)
# Out:
# 200

# %%
ufo_df = pd.DataFrame(list(zip(occured, city, state, country, shape, summary, reported, posted, image)), columns=['occured', 'city', 'state', 'country', 'shape', 'summary', 'reported', 'posted', 'image'])

# %%
ufo_df.sort_values('occured', ascending=True)
# Out:
#               occured           city state country    shape  \
# 128  01/01/1990 00:00    Minneapolis    MN     USA
# 28   01/01/1990 00:00    Minneapolis    MN     USA
# 129  01/01/1993 00:00    Reedborough    VT     USA
# 29   01/01/1993 00:00    Reedborough    VT     USA
# 155  01/01/1995 00:02  Pacific Grove    CA     USA
# ..                ...            ...   ...     ...      ...
# 3    12/13/1994 18:55         Murphy    NC     USA
# 95   12/29/1994 21:45      La Crosse    WA     USA  Chevron
# 195  12/29/1994 21:45      La Crosse    WA     USA  Chevron
# 194  12/31/1994 22:00           Orem    UT     USA
# 94   12/31/1994 22:00           Orem    UT     USA
#
#                                                summary    reported  \
# 128  Man reports seeing 5x objects connected by "a ...  02/10/1995
# 28   Man reports seeing 5x objects connected by "a ...  02/10/1995
# 129  Man reports witnessing UFO two years prior.  (...  02/10/1995
# 29   Man reports witnessing UFO two years prior.  (...  02/10/1995
# 155  Rept. that local police had pursued a strange ...  02/20/1995
# ..                                                 ...         ...
# 3    Woman reports seeing strange, lighted obj. wit...  02/03/1995
# 95   Three seemingly identical black, delta-shaped,...  01/01/1995
# 195  Three seemingly identical black, delta-shaped,...  01/01/1995
# 194  Man & wife, and four neighbors witnessed a str...  01/01/1995
# 94   Man & wife, and four neighbors witnessed a str...  01/01/1995
#
#          posted image
# 128  11/02/1999
# 28   11/02/1999
# 129  11/02/1999
# 29   11/02/1999
# 155  11/02/1999
# ..          ...   ...
# 3    11/02/1999
# 95   11/20/2001     Y
# 195  11/20/2001     Y
# 194  11/20/2001
# 94   11/20/2001
#
# [200 rows x 9 columns]

# %%
ufo_df.to_csv('prelim.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27496/3977458492.py in <module>
# ----> 1 ufo_df.to_csv('prelim.csv')
#
# c:\Users\tkwhi\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# c:\Users\tkwhi\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# c:\Users\tkwhi\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     235         """
#     236         # apply compression and byte/text conversion
# --> 237         with get_handle(
#     238             self.filepath_or_buffer,
#     239             self.mode,
#
# c:\Users\tkwhi\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# PermissionError: [Errno 13] Permission denied: 'prelim.csv'
