# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import requests
from bs4 import BeautifulSoup as BS
import re
import time

# %%
url = 'https://nuforc.org/wp-admin/admin-ajax.php?action=get_wdtable&table_id=1&wdt_var1=Post&wdt_var2=-1'
params = {
    'action': 'get_wdtable',
    'table_id': '1',
    'wdt_var1': 'Post',
    'wdt_var2': '-1',
}

data = {
    'draw': '1',
    'start': '0',
    'length': '80000',
    'search[value]': '',
    'search[regex]': 'false',
    'wdtNonce': '2ad4551c87',  # This looks like a security nonce, ensure it's correctly handled
}

data.update({
    'order[0][column]': '1',
    'order[0][dir]': 'desc',
})

r = requests.post(url, params=params, data=data)

r
# Out:
# <Response [200]>

# %%
url = 'https://nuforc.org/wp-admin/admin-ajax.php?action=get_wdtable&table_id=1&wdt_var1=Post&wdt_var2=-1'
params = {
    'action': 'get_wdtable',
    'table_id': '1',
    'wdt_var1': 'Post',
    'wdt_var2': '-1',
}

data = {
    'draw': '1',
    'start': '0',
    'length': '80000',
    'search[value]': '',
    'search[regex]': 'false',
    'wdtNonce': '9cc2436813',  # This looks like a security nonce, ensure it's correctly handled
}

data.update({
    'order[0][column]': '1',
    'order[0][dir]': 'desc',
})

r = requests.post(url, params=params, data=data)

r
# Out:
# <Response [200]>

# %%
ufo = r.json()

# %%
ufo_df2 = pd.DataFrame(ufo['data'])
ufo_df2.head()
# Out:
#                                                    0                 1  \
# 0  <a data-content='Open' href='/sighting/?id=180...  02/15/2024 14:20
# 1  <a data-content='Open' href='/sighting/?id=180...  02/15/2024 06:21
# 2  <a data-content='Open' href='/sighting/?id=180...  02/15/2024 02:30
# 3  <a data-content='Open' href='/sighting/?id=180...  02/14/2024 22:45
# 4  <a data-content='Open' href='/sighting/?id=180...  02/14/2024 22:44
#
#                 2                3          4          5  \
# 0  Shepherdsville               KY        USA        Orb
# 1      Greenville               SC        USA     Circle
# 2   Mount Gambier  South Australia  Australia  Formation
# 3            None               VA        USA      Light
# 4          Somers               CT        USA    Unknown
#
#                                                    6           7           8  \
# 0              Several sightings over several years.  02/15/2024  02/15/2024
# 1  Object moving slowing across the sky, suddenly...  02/15/2024  02/15/2024
# 2  All were low, groups of two stars moving about...  02/14/2024  02/15/2024
# 3  Standing to the west of this object it hung in...  02/15/2024  02/15/2024
# 4  Odd, flashing object I could only describe dur...  02/14/2024  02/15/2024
#
#       9
# 0  None
# 1  None
# 2  None
# 3  None
# 4     Y

# %%
ufo_df1 = pd.DataFrame(ufo['data'])
ufo_df1.head()
# Out:
#                                                    0                 1  \
# 0  <a data-content='Open' href='/sighting/?id=180...  02/15/2024 14:20
# 1  <a data-content='Open' href='/sighting/?id=180...  02/15/2024 06:21
# 2  <a data-content='Open' href='/sighting/?id=180...  02/15/2024 02:30
# 3  <a data-content='Open' href='/sighting/?id=180...  02/14/2024 22:45
# 4  <a data-content='Open' href='/sighting/?id=180...  02/14/2024 22:44
#
#                 2                3          4          5  \
# 0  Shepherdsville               KY        USA        Orb
# 1      Greenville               SC        USA     Circle
# 2   Mount Gambier  South Australia  Australia  Formation
# 3            None               VA        USA      Light
# 4          Somers               CT        USA    Unknown
#
#                                                    6           7           8  \
# 0              Several sightings over several years.  02/15/2024  02/15/2024
# 1  Object moving slowing across the sky, suddenly...  02/15/2024  02/15/2024
# 2  All were low, groups of two stars moving about...  02/14/2024  02/15/2024
# 3  Standing to the west of this object it hung in...  02/15/2024  02/15/2024
# 4  Odd, flashing object I could only describe dur...  02/14/2024  02/15/2024
#
#       9
# 0  None
# 1  None
# 2  None
# 3  None
# 4     Y

# %%
ufo_df3 = pd.concat([ufo_df1,ufo_df2])
ufo_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 160000 entries, 0 to 79999
# Data columns (total 10 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       160000 non-null  object
#  1   1       160000 non-null  object
#  2   2       159288 non-null  object
#  3   3       154900 non-null  object
#  4   4       160000 non-null  object
#  5   5       152826 non-null  object
#  6   6       159924 non-null  object
#  7   7       160000 non-null  object
#  8   8       160000 non-null  object
#  9   9       8360 non-null    object
# dtypes: object(10)
# memory usage: 13.4+ MB

# %%
ufo_df3
# Out:
#                                                        0                 1  \
# 0      <a data-content='Open' href='/sighting/?id=180...  02/15/2024 14:20
# 1      <a data-content='Open' href='/sighting/?id=180...  02/15/2024 06:21
# 2      <a data-content='Open' href='/sighting/?id=180...  02/15/2024 02:30
# 3      <a data-content='Open' href='/sighting/?id=180...  02/14/2024 22:45
# 4      <a data-content='Open' href='/sighting/?id=180...  02/14/2024 22:44
# ...                                                  ...               ...
# 79995  <a data-content='Open' href='/sighting/?id=805...  11/23/2010 18:00
# 79996  <a data-content='Open' href='/sighting/?id=108...  11/23/2010 16:55
# 79997  <a data-content='Open' href='/sighting/?id=791...  11/23/2010 06:30
# 79998  <a data-content='Open' href='/sighting/?id=790...  11/23/2010 06:00
# 79999  <a data-content='Open' href='/sighting/?id=790...  11/23/2010 05:49
#
#                                                2                3          4  \
# 0                                 Shepherdsville               KY        USA
# 1                                     Greenville               SC        USA
# 2                                  Mount Gambier  South Australia  Australia
# 3                                           None               VA        USA
# 4                                         Somers               CT        USA
# ...                                          ...              ...        ...
# 79995                               North Bergen               NJ        USA
# 79996  Albany (3 hrs W of; on I-90 near Exit 44)               NY        USA
# 79997                            Monument Valley               UT        USA
# 79998                                  Washougal               WA        USA
# 79999                              North Babylon               NY        USA
#
#                5                                                  6  \
# 0            Orb              Several sightings over several years.
# 1         Circle  Object moving slowing across the sky, suddenly...
# 2      Formation  All were low, groups of two stars moving about...
# 3          Light  Standing to the west of this object it hung in...
# 4        Unknown  Odd, flashing object I could only describe dur...
# ...          ...                                                ...
# 79995      Other  THE OBJECT CHANGED COLOURS OVER NYC& N.J. IN H...
# 79996      Other  Gun metal black crescent with 6 window-glowing...
# 79997   Changing  looked like a worm in the sky oozing off itsel...
# 79998       Oval           Bright big oval shaped light in the sky.
# 79999      Other  I could see 5 lights around the bottom, closes...
#
#                 7           8     9
# 0      02/15/2024  02/15/2024  None
# 1      02/15/2024  02/15/2024  None
# 2      02/14/2024  02/15/2024  None
# 3      02/15/2024  02/15/2024  None
# 4      02/14/2024  02/15/2024     Y
# ...           ...         ...   ...
# 79995  03/22/2011  03/23/2011  None
# 79996  03/28/2014  04/04/2014  None
# 79997  12/02/2010  01/05/2011  None
# 79998  11/27/2010  01/05/2011  None
# 79999  11/23/2010  01/05/2011  None
#
# [160000 rows x 10 columns]

# %%
ufo_df3.columns = [
    'image_link',
    'occurred',
    'city',
    'state',
    'country',
    'shape',
    'summary',
    'reported',
    'posted',
    'image']

ufo_df3
# Out:
#                                               image_link          occurred  \
# 0      <a data-content='Open' href='/sighting/?id=180...  02/15/2024 14:20
# 1      <a data-content='Open' href='/sighting/?id=180...  02/15/2024 06:21
# 2      <a data-content='Open' href='/sighting/?id=180...  02/15/2024 02:30
# 3      <a data-content='Open' href='/sighting/?id=180...  02/14/2024 22:45
# 4      <a data-content='Open' href='/sighting/?id=180...  02/14/2024 22:44
# ...                                                  ...               ...
# 79995  <a data-content='Open' href='/sighting/?id=805...  11/23/2010 18:00
# 79996  <a data-content='Open' href='/sighting/?id=108...  11/23/2010 16:55
# 79997  <a data-content='Open' href='/sighting/?id=791...  11/23/2010 06:30
# 79998  <a data-content='Open' href='/sighting/?id=790...  11/23/2010 06:00
# 79999  <a data-content='Open' href='/sighting/?id=790...  11/23/2010 05:49
#
#                                             city            state    country  \
# 0                                 Shepherdsville               KY        USA
# 1                                     Greenville               SC        USA
# 2                                  Mount Gambier  South Australia  Australia
# 3                                           None               VA        USA
# 4                                         Somers               CT        USA
# ...                                          ...              ...        ...
# 79995                               North Bergen               NJ        USA
# 79996  Albany (3 hrs W of; on I-90 near Exit 44)               NY        USA
# 79997                            Monument Valley               UT        USA
# 79998                                  Washougal               WA        USA
# 79999                              North Babylon               NY        USA
#
#            shape                                            summary  \
# 0            Orb              Several sightings over several years.
# 1         Circle  Object moving slowing across the sky, suddenly...
# 2      Formation  All were low, groups of two stars moving about...
# 3          Light  Standing to the west of this object it hung in...
# 4        Unknown  Odd, flashing object I could only describe dur...
# ...          ...                                                ...
# 79995      Other  THE OBJECT CHANGED COLOURS OVER NYC& N.J. IN H...
# 79996      Other  Gun metal black crescent with 6 window-glowing...
# 79997   Changing  looked like a worm in the sky oozing off itsel...
# 79998       Oval           Bright big oval shaped light in the sky.
# 79999      Other  I could see 5 lights around the bottom, closes...
#
#          reported      posted image
# 0      02/15/2024  02/15/2024  None
# 1      02/15/2024  02/15/2024  None
# 2      02/14/2024  02/15/2024  None
# 3      02/15/2024  02/15/2024  None
# 4      02/14/2024  02/15/2024     Y
# ...           ...         ...   ...
# 79995  03/22/2011  03/23/2011  None
# 79996  03/28/2014  04/04/2014  None
# 79997  12/02/2010  01/05/2011  None
# 79998  11/27/2010  01/05/2011  None
# 79999  11/23/2010  01/05/2011  None
#
# [160000 rows x 10 columns]

# %%
ufo_df3.to_csv('nuforc.csv')
